# %% [markdown]
# ## Iron Distribution is Global Oceans : GEOTRACES

# %% [markdown]
# #### Install Dependencies and Import

# %%
# !pip install geopy
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import geopy.distance
import pandas as pd
pd.options.display.max_seq_items = 2000

# %% [markdown]
# ### Data Sources
# https://geotraces.webodv.awi.de/service/IDP2021%3EGEOTRACES_IDP2021_Seawater_Discrete_Sample_Data_v1
# https://www.pmel.noaa.gov/eoi/PlumeStudies/global-vents/global-vents-text.html

# %% [markdown]
# ### Data Loading and Preprocessing

# %%
def get_distance(lat1, long1, lat2, long2):
    return geopy.distance.geodesic((lat1, long1), (lat2, long2)).km

# %%
vents = pd.read_csv('HydrothermalVents.csv',low_memory=False)
vents = vents[vents['Activity'] != 'inactive']
#vents = vents[vents['Activity'] == 'active']

vents = vents[vents['Depth'].notnull()]
vents = vents[vents['Depth'] != '0']
vents = vents[vents['Depth'] != 'NotProvided']

vents
# Out:
#                                    Name longitude   latitude  \
# 0                        Kagamil Island   -169.72      52.98
# 1                Piip Submarine Volcano  167.2717    55.4167
# 3    Kraternaya Bight; Ushishir Volcano     152.8  47.516667
# 4          Hot Beach; Mendeleev Volcano   145.736     43.976
# 5    Kagoshima Bay; Sakura-jima Volcano     130.8      31.65
# ..                                  ...       ...        ...
# 549                            SEIR; 21    79.103    -41.252
# 550                            SEIR; 16    79.753    -41.772
# 551                            SEIR; 10    81.838    -41.802
# 552                            SEIR; 01    88.042    -42.113
# 553                           SEIR; 08A     82.71    -42.477
#
#           Site Activity     Activity Tectonic setting Spreading Rate    Depth
# 0    VolcanicArc-active       active      arc volcano  NotApplicable        5
# ...

# %%
#If a depth contains a range of values, replace it with the average of the range

cur_index = 0
indices = vents.index
for d in vents['Depth'].values:
    d = d.replace(' ', '')
    if('-' in d):
        num1 = d[:d.index('-')]
        print(num1)
        num2 = d[d.index('-')+1:]
        print(num2)

        average_d = (int(num1)+int(num2)) / 2

        vents.loc[indices[cur_index],'DepthAverage'] = int(average_d)
    else:
        print(int(d))
        vents.loc[indices[cur_index],'DepthAverage'] = int(d)
    
    cur_index = cur_index + 1
# Out:
# 5
# 500
# 382
# 60
# 0
# 1
# 0
# 200
# 80
# 4
# 0
# 23
# 10
# 521
# 779
# 740
# 610
# 1070
# 970
# 1600
# 1430
# 1390
# 1450
# 1340
# 1850
# 1650
# 1000
# 1520
# 1460
# 1385
# 1336
# 1200
# 250
# 30
# 10
# 1360
# 1220
# 1110
# 850
# 690
# 670
# 1380
# 1320
# 1200
# 870
# 520
# 440
# 930
# 460
# 800
# 700
# 1600
# 1530
# 600
# 430
# 2150
# 1750
# 1100
# 500
# 400
# 1604
# 1573
# 1140
# 450
# 350
# 875
# 420
# 60
# 55
# 144
# 460
# 457
# 179
# 214
# 200
# 323
# 50
# 599
# 516
# 1150
# 1470
# 1450
# 1290
# 2960
# 3640
# 3595
# 3676
# 3600
# 2900
# 2880
# 2990
# 2830
# 2880
# 10
# 3
# 3
# 1000
# 535
# 500
# 1308
# 1500
# 1300
# 1039
# 1025
# 2500
# 2240
# 2190
# 2500
# 2163
# 2147
# 2000
# 1800
# 1650
# 2000
# 1940
# 1520
# 1460
# 30
# 0
# 1200
# 30
# 0
# 1450
# 10
# 5
# 2366
# 2143
# 3300
# 3550
# 650
# 500
# 200
# 2000
# 600
# 2000
# 800
# 1600
# 450
# 1425
# 450
# 165
# 300
# 464
# 250
# 100
# 1600
# 1400
# 1900
# 980
# 940
# 2335
# 1860
# 3900
# 3200
# 1980
# 2000
# 1960
# 2700
# ...

# %%
vents
# Out:
#                                    Name longitude   latitude  \
# 0                        Kagamil Island   -169.72      52.98
# 1                Piip Submarine Volcano  167.2717    55.4167
# 3    Kraternaya Bight; Ushishir Volcano     152.8  47.516667
# 4          Hot Beach; Mendeleev Volcano   145.736     43.976
# 5    Kagoshima Bay; Sakura-jima Volcano     130.8      31.65
# ..                                  ...       ...        ...
# 549                            SEIR; 21    79.103    -41.252
# 550                            SEIR; 16    79.753    -41.772
# 551                            SEIR; 10    81.838    -41.802
# 552                            SEIR; 01    88.042    -42.113
# 553                           SEIR; 08A     82.71    -42.477
#
#           Site Activity     Activity Tectonic setting Spreading Rate    Depth  \
# 0    VolcanicArc-active       active      arc volcano  NotApplicable        5
# ...

# %%
geotraces = pd.read_csv('GEOTRACES_IDP2021_Seawater_Discrete_Sample_Data_v1.csv',low_memory=False)
geotraces.columns = [c.replace(' ', '_') for c in geotraces.columns]
geotraces.columns = [c.replace(':', '_') for c in geotraces.columns]
geotraces_iron = geotraces[geotraces['Fe_D_CONC_BOTTLE_[nmol/kg]'].notnull()]

geotraces_iron = geotraces_iron[['Station_METAVAR_INDEXED_TEXT', 'yyyy-mm-ddThh_mm_ss.sss', 'Longitude_[degrees_east]', 'Latitude_[degrees_north]', 'Fe_D_CONC_BOTTLE_[nmol/kg]']]

geotraces_iron.rename(columns={'Station_METAVAR_INDEXED_TEXT': 'StationID', 'yyyy-mm-ddThh_mm_ss.sss': 'dateTime', 'Longitude_[degrees_east]': 'lon', 'Latitude_[degrees_north]':'lat', 'Fe_D_CONC_BOTTLE_[nmol/kg]':'dFe'}, inplace=True)

geotraces_iron = geotraces_iron.drop_duplicates()

# %%
geotraces_iron
# Out:
#       StationID             dateTime        lon      lat       dFe
# 57            1  2014-05-19T18:18:54  349.96399  40.3333  1.040000
# 97            1  2014-05-19T18:18:54  349.96399  40.3333  0.500000
# 108           1  2014-05-19T18:18:54  349.96399  40.3333  0.720000
# 122           1  2014-05-19T18:18:54  349.96399  40.3333  0.820000
# 133           1  2014-05-19T18:18:54  349.96399  40.3333  0.940000
# ...         ...                  ...        ...      ...       ...
# 96053       103  2017-03-16T07:30:00   14.07490 -43.9816  0.123072
# 96054       103  2017-03-16T07:30:00   14.07490 -43.9816  0.095389
# 96055       103  2017-03-16T07:30:00   14.07490 -43.9816  0.459403
# 96056       103  2017-03-16T07:30:00   14.07490 -43.9816  0.509960
# 96057       103  2017-03-16T07:30:00   14.07490 -43.9816  0.544835
#
# [13614 rows x 5 columns]

# %% [markdown]
# ### Visualizations

# %%
import plotly.express as px
df = geotraces_iron
fig1 = px.scatter_geo(geotraces_iron, lon = geotraces_iron['lon'], lat = geotraces_iron['lat'], color="dFe",
                     #hover_name="country", size="pop",
                     projection="natural earth", range_color =[0,1.5], color_continuous_scale = ['aquamarine', 'coral'])
fig1.show()
# Out:
# <div>                            <div id="e249a450-dc83-4e7c-83df-16fe14dbb569" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e249a450-dc83-4e7c-83df-16fe14dbb569")) {                    Plotly.newPlot(                        "e249a450-dc83-4e7c-83df-16fe14dbb569",                        [{"geo":"geo","hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>dFe=%{marker.color}<extra></extra>","lat":[40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3331,40.3331,40.3331,40.3331,40.3331,40.3331,40.3331,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3333,40.3325,40.3325,40.3325,40.3325,40.3325,40.3325,40.332
# ...

# %%
import plotly.express as px
df = geotraces_iron
fig2 = px.scatter_geo(vents, lon = vents['longitude'], lat = vents['latitude'], color="DepthAverage",
                     #hover_name="country", size="pop",
                     projection="natural earth", range_color =[0,5000], color_continuous_scale = ['aquamarine', 'darkblue'])
fig2.show()
# Out:
# <div>                            <div id="676f2c8d-9877-4f9d-b3cf-830096c14418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("676f2c8d-9877-4f9d-b3cf-830096c14418")) {                    Plotly.newPlot(                        "676f2c8d-9877-4f9d-b3cf-830096c14418",                        [{"geo":"geo","hovertemplate":"latitude=%{lat}<br>longitude=%{lon}<br>DepthAverage=%{marker.color}<extra></extra>","lat":["52.98","55.4167","47.516667","43.976","31.65","30.75","24.348333","30.330333","28.813667","28.3917","27.786333","27.575","27.541667","27.266667","25.23","24.866667","24.855","24.849","24.83333","24.833333","32.1","31.883333","31.466667","28.575","28.32","27.683333","26.7","32","31.1","23.083333","22.508","22.387","21.93","21.6","21.485","21.38
# ...

# %% [markdown]
# ### Exploring Correlations

# %%
def shortest_distance_to_vent():
    
    vent_lats = list(vents.latitude)
    vent_lons = list(vents.longitude)

    
    for index, row in geotraces_iron.iterrows():
        print(index)
        station_lon = row['lon']
        station_lat = row['lat']
        
        #print('Station Lat: ', station_lat)
        #print('Station Long: ', station_lon)

        smallest_distance_to_vent = 9999
        distance = 9999
        for i in range(len(vent_lats)):
           # print(vent_lats[i], vent_lons[i], station_lat, station_lon)
            distance = get_distance(vent_lats[i], vent_lons[i], station_lat, station_lon)
            if(distance < smallest_distance_to_vent):
                smallest_distance_to_vent = distance
        
        #print('Smallest Distance to Vent: ', smallest_distance_to_vent)
        geotraces_iron.loc[index, 'DistanceToNearestVent'] = smallest_distance_to_vent
    
shortest_distance_to_vent()
# Out:
# 57
# 97
# 108
# 122
# 133
# 143
# 155
# 157
# 170
# 173
# 179
# 183
# 192
# 204
# 210
# 224
# 230
# 237
# 251
# 254
# 266
# 280
# 291
# 295
# 299
# 305
# 311
# 315
# 349
# 353
# 356
# 366
# 371
# 374
# 377
# 379
# 382
# 387
# 389
# 539
# 544
# 549
# 557
# 563
# 567
# 575
# 579
# 581
# 583
# 585
# 588
# 591
# 596
# 597
# 600
# 602
# 604
# 606
# 644
# 673
# 685
# 705
# 722
# 739
# 747
# 760
# 767
# 908
# 911
# 916
# 922
# 925
# 929
# 939
# 942
# 944
# 946
# 951
# 952
# 955
# 957
# 959
# 964
# 966
# 969
# 972
# 973
# 1004
# 1010
# 1013
# 1018
# 1021
# 1037
# 1038
# 1040
# 1043
# 1046
# 1049
# 1050
# 1053
# 1056
# 1062
# 1065
# 1101
# 1105
# 1109
# 1112
# 1130
# 1134
# 1136
# 1138
# 1140
# 1143
# 1144
# 1147
# 1149
# 1153
# 1155
# 1157
# 1159
# 1162
# 1223
# 1244
# 1255
# 1278
# 1309
# 1325
# 1333
# 1357
# 1367
# 1381
# 1386
# 1393
# 1403
# 1406
# 1420
# 1427
# 1450
# 1461
# 1496
# 1498
# 1501
# 1507
# 1512
# 1519
# 1524
# 1529
# 1531
# 1539
# 1541
# 1543
# 1545
# 1546
# 1549
# 1552
# ...

# %%
geotraces_iron['dFe'].corr(geotraces_iron['DistanceToNearestVent'])
# Out:
# -0.014913004509927687

# %%
geotraces_iron
# Out:
#       StationID             dateTime        lon      lat       dFe  \
# 57            1  2014-05-19T18:18:54  349.96399  40.3333  1.040000
# 97            1  2014-05-19T18:18:54  349.96399  40.3333  0.500000
# 108           1  2014-05-19T18:18:54  349.96399  40.3333  0.720000
# 122           1  2014-05-19T18:18:54  349.96399  40.3333  0.820000
# 133           1  2014-05-19T18:18:54  349.96399  40.3333  0.940000
# ...         ...                  ...        ...      ...       ...
# 96053       103  2017-03-16T07:30:00   14.07490 -43.9816  0.123072
# 96054       103  2017-03-16T07:30:00   14.07490 -43.9816  0.095389
# 96055       103  2017-03-16T07:30:00   14.07490 -43.9816  0.459403
# 96056       103  2017-03-16T07:30:00   14.07490 -43.9816  0.509960
# 96057       103  2017-03-16T07:30:00   14.07490 -43.9816  0.544835
#
#        DistanceToNearestVent
# 57               1448.450084
# 97               1448.450084
# 108              1448.450084
# 122              1448.450084
# ...

# %%
geotraces.columns
# Out:
# Index(['Cruise', 'Station_METAVAR_INDEXED_TEXT', 'Type',
#        'yyyy-mm-ddThh_mm_ss.sss', 'Longitude_[degrees_east]',
#        'Latitude_[degrees_north]', 'Bot._Depth_[m]',
#        'Operator's_Cruise_Name_METAVAR_INDEXED_TEXT',
#        'Ship_Name_METAVAR_INDEXED_TEXT', 'Period_METAVAR_INDEXED_TEXT',
#        'Chief_Scientist_METAVAR_INDEXED_TEXT',
#        'GEOTRACES_Scientist_METAVAR_INDEXED_TEXT',
#        'Cruise_Aliases_METAVAR_INDEXED_TEXT',
#        'Cruise_Information_Link_METAVAR_INDEXED_TEXT',
#        'BODC_Cruise_Number_METAVAR_INTEGER', 'CTDPRS_T_VALUE_SENSOR_[dbar]',
#        'QV_SEADATANET', 'DEPTH_[m]', 'QV_SEADATANET.1',
#        'Rosette_Bottle_Number_INTEGER', 'QV_SEADATANET.2',
#        'GEOTRACES_Sample_ID_INDEXED_TEXT', 'QV_SEADATANET.3',
#        'Bottle_Flag_INDEXED_TEXT', 'QV_SEADATANET.4',
#        'Cast_Identifier_INDEXED_TEXT', 'QV_SEADATANET.5',
#        'Sampling_Device_INDEXED_TEXT', 'QV_SEADATANET.6',
# ...
